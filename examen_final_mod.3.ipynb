# %% [markdown]
# ---------------------------------------FASE 1: EDA--------------------------------------------------

# %%
import pandas as pd #hago las importaciones de librerias.
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import warnings # para que no se imprimam los future warning
warnings.filterwarnings('ignore', category=FutureWarning)

# %%
pd.set_option('display.max_columns', None) # para que se muestren todas las columnas del dataframe al imprimirlo.

# %%
df_1= pd.read_csv("files/Customer Flight Activity.csv") # cargo el dataframe con el csv que me han dado.

# %%
df_2= pd.read_csv("files/Customer Loyalty History.csv")

# %%
df_1.head(5) #exploro el dataframe para ver su estructura y las columnas que tiene.
# Out:
#    Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 0          100018  2017      1               3                        0
# 1          100102  2017      1              10                        4
# 2          100140  2017      1               6                        0
# 3          100214  2017      1               0                        0
# 4          100272  2017      1               0                        0
#
#    Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 0              3      1521               152.0                0
# 1             14      2030               203.0                0
# 2              6      1200               120.0                0
# 3              0         0                 0.0                0
# 4              0         0                 0.0                0
#
#    Dollar Cost Points Redeemed
# 0                            0
# 1                            0
# 2                            0
# ...

# %%
df_2.head(5) #exploro el segundo dataframe para ver su estructura y las columnas que tiene, y comprobar que la columna "Loyalty Number" es la misma en ambos dataframes, lo que me indica que podre unirlos por un "Merge"
# Out:
#    Loyalty Number Country          Province       City Postal Code  Gender  \
# 0          480934  Canada           Ontario    Toronto     M2Z 4K1  Female
# 1          549612  Canada           Alberta   Edmonton     T3G 6Y6    Male
# 2          429460  Canada  British Columbia  Vancouver     V6E 3D9    Male
# 3          608370  Canada           Ontario    Toronto     P1W 1K4    Male
# 4          530508  Canada            Quebec       Hull     J8Y 3Z5    Male
#
#   Education    Salary Marital Status Loyalty Card      CLV Enrollment Type  \
# 0  Bachelor   83236.0        Married         Star  3839.14        Standard
# 1   College       NaN       Divorced         Star  3839.61        Standard
# 2   College       NaN         Single         Star  3839.75        Standard
# 3   College       NaN         Single         Star  3839.75        Standard
# 4  Bachelor  103495.0        Married         Star  3842.79        Standard
#
# ...

# %%
df_1.sample(5) # muestra 5 filas aleatorias del dataframe para ver si hay alguna fila con valores nulos o algún valor extraño.
# Out:
#         Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 196953          687108  2017     12               0                        0
# 275886          393329  2018      5               0                        0
# 102909          181434  2017      7               0                        0
# 236185          662022  2018      4               4                        0
# 266751          802023  2018      4               0                        0
#
#         Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 196953              0         0                0.00                0
# 275886              0         0                0.00                0
# 102909              0         0                0.00                0
# 236185              4      1516              163.08                0
# 266751              0         0                0.00                0
#
#         Dollar Cost Points Redeemed
# 196953                            0
# ...

# %%
df_2.sample(5) # muestra 5 filas aleatorias del segundo dataframe para ver si hay alguna fila con valores nulos o algún valor extraño.
# Out:
#        Loyalty Number Country          Province      City Postal Code  Gender  \
# 10221          932513  Canada           Ontario   Toronto     M8Y 4K8    Male
# 11250          897716  Canada           Ontario   Toronto     P1W 1K4  Female
# 9086           900505  Canada  British Columbia  Victoria     V10 6T5    Male
# 9155           257236  Canada           Ontario   Toronto     M2M 6J7    Male
# 5558           769976  Canada          Manitoba  Winnipeg     R3R 3T4    Male
#
#       Education   Salary Marital Status Loyalty Card       CLV  \
# 10221  Bachelor  65760.0         Single         Star   2364.43
# 11250  Bachelor  67988.0        Married         Star   2597.86
# 9086   Bachelor  66994.0        Married         Nova  13334.27
# 9155   Bachelor  88320.0        Married         Nova  13976.52
# 5558    College      NaN        Married         Nova   4004.55
#
#       Enrollment Type  Enrollment Year  Enrollment Month  Cancellation Year  \
# ...

# %%
df_1.shape #busco el numero de filas y columnas del dataframe para tener una idea de su tamaño.
# Out:
# (405624, 10)

# %%
df_2.shape #busco el numero de filas y columnas del segundo dataframe para tener una idea de su tamaño.
# Out:
# (16737, 16)

# %%
df_2.describe(include= "str").T #busco una descripción de las columnas de tipo string para ver si hay alguna columna con valores nulos o algún valor extraño, y para tener una idea de los valores que hay en cada columna.
# compruebo que la columna Country tiene un valor unico con una alta frecuencia y que es candidata a a ser eliminada portque no aporta info relevante.
# Out:
#                  count unique       top   freq
# Country          16737      1    Canada  16737
# Province         16737     11   Ontario   5404
# City             16737     29   Toronto   3351
# Postal Code      16737     55   V6E 3D9    911
# Gender           16737      2    Female   8410
# Education        16737      5  Bachelor  10475
# Marital Status   16737      3   Married   9735
# Loyalty Card     16737      3      Star   7637
# Enrollment Type  16737      2  Standard  15766

# %%
df_1.duplicated().sum() # busco si hay filas duplicadas en el dataframe para eliminarlas si las hay, ya que no aportan información relevante y pueden sesgar los resultados.
# Out:
# np.int64(1864)

# %%
df_2.duplicated().sum() #hago lo mismo en el segundo dataframe.
# Out:
# np.int64(0)

# %%
df_1[df_1.duplicated(keep=False)].value_counts() #busco los duplicados y cuantas veces se repiten
# Out:
# Loyalty Number  Year  Month  Flights Booked  Flights with Companions  Total Flights  Distance  Points Accumulated  Points Redeemed  Dollar Cost Points Redeemed
# 678205          2017  1      0               0                        0              0         0.0                 0                0                              3
#                       2      0               0                        0              0         0.0                 0                0                              3
#                       3      0               0                        0              0         0.0                 0                0                              3
#                       4      0               0                        0              0         0.0                 0                0                              3
#                       5      0               0                        0              0         0.0                 0                0                              3
# ...

# %%
df_2.isna().sum()/df_2.shape[0]*100 #busco el porcentaje de valores nulos por columna, divido el numero de valores nulos por el numero total de filas y multiplico por 100 para obtener el porcentaje
# Out:
# Loyalty Number         0.000000
# Country                0.000000
# Province               0.000000
# City                   0.000000
# Postal Code            0.000000
# Gender                 0.000000
# Education              0.000000
# Salary                25.321145
# Marital Status         0.000000
# Loyalty Card           0.000000
# CLV                    0.000000
# Enrollment Type        0.000000
# Enrollment Year        0.000000
# Enrollment Month       0.000000
# Cancellation Year     87.650117
# Cancellation Month    87.650117
# dtype: float64

# %%
df_1.isna().sum()/df_1.shape[0]*100 # busco el porcentaje de valores nulos por columna, divido el numero de valores nulos por el numero total de filas y multiplico por 100 para obtener el porcentaje
# Out:
# Loyalty Number                 0.0
# Year                           0.0
# Month                          0.0
# Flights Booked                 0.0
# Flights with Companions        0.0
# Total Flights                  0.0
# Distance                       0.0
# Points Accumulated             0.0
# Points Redeemed                0.0
# Dollar Cost Points Redeemed    0.0
# dtype: float64

# %%
df_1= df_1.drop_duplicates() #elimino las filas duplicadas

# %%
df_1.duplicated().sum() #compruebo que ya no hay filas duplicadas
# Out:
# np.int64(0)

# %%
df = pd.merge(df_1, df_2, on='Loyalty Number', how='left') # hago un merge de los dos dataframes utilizando la columna "Loyalty Number" como clave, y utilizando un left join para que se mantengan todas las filas del dataframe 1 y se añadan las columnas del dataframe 2 donde coincidan los valores de "Loyalty Number". Las filas del dataframe 1 que no tengan un valor coincidente en el dataframe 2 tendrán valores nulos en las columnas añadidas.

# %%
df.head(5) # compruebo que el merge se ha hecho correctamente y que se han añadido las columnas del dataframe 2 al dataframe 1.
# Out:
#    Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 0          100018  2017      1               3                        0
# 1          100102  2017      1              10                        4
# 2          100140  2017      1               6                        0
# 3          100214  2017      1               0                        0
# 4          100272  2017      1               0                        0
#
#    Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 0              3      1521               152.0                0
# 1             14      2030               203.0                0
# 2              6      1200               120.0                0
# 3              0         0                 0.0                0
# 4              0         0                 0.0                0
#
#    Dollar Cost Points Redeemed Country          Province          City  \
# 0                            0  Canada           Alberta      Edmonton
# ...

# %% [markdown]
# ----------------------------------FASE 2: LIMPIEZA------------------------------------------

# %%
df[df.duplicated(keep=False)].sort_values("Loyalty Number") #busco si hay filas duplicadas en el nuevo dataframe, y las ordeno por la columna "Loyalty Number" para ver si hay filas con el mismo valor en esa columna.
# Out:
# Empty DataFrame
# Columns: [Loyalty Number, Year, Month, Flights Booked, Flights with Companions, Total Flights, Distance, Points Accumulated, Points Redeemed, Dollar Cost Points Redeemed, Country, Province, City, Postal Code, Gender, Education, Salary, Marital Status, Loyalty Card, CLV, Enrollment Type, Enrollment Year, Enrollment Month, Cancellation Year, Cancellation Month]
# Index: []

# %%
df.duplicated().sum() #compruebo que no hay filas duplicadas en el nuevo dataframe
# Out:
# np.int64(0)

# %%
df.drop(columns=["Country"], inplace=True) #elimino la columna Country ya que no aporta valor al esquema.

# %%
df.head(5) #compruebo que efectivamente la columna esta eliminada.
# Out:
#    Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 0          100018  2017      1               3                        0
# 1          100102  2017      1              10                        4
# 2          100140  2017      1               6                        0
# 3          100214  2017      1               0                        0
# 4          100272  2017      1               0                        0
#
#    Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 0              3      1521               152.0                0
# 1             14      2030               203.0                0
# 2              6      1200               120.0                0
# 3              0         0                 0.0                0
# 4              0         0                 0.0                0
#
#    Dollar Cost Points Redeemed          Province          City Postal Code  \
# ...

# %%
df.info() #compruebo el tipo de datos de cada columna para ver si hay que hacer alguna conversión de tipo de datos, y para tener una idea de la cantidad de valores no nulos en cada columna.
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 403760 entries, 0 to 403759
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Loyalty Number               403760 non-null  int64
#  1   Year                         403760 non-null  int64
#  2   Month                        403760 non-null  int64
#  3   Flights Booked               403760 non-null  int64
#  4   Flights with Companions      403760 non-null  int64
#  5   Total Flights                403760 non-null  int64
#  6   Distance                     403760 non-null  int64
#  7   Points Accumulated           403760 non-null  float64
#  8   Points Redeemed              403760 non-null  int64
#  9   Dollar Cost Points Redeemed  403760 non-null  int64
#  10  Province                     403760 non-null  str
#  11  City                         403760 non-null  str
#  12  Postal Code                  403760 non-null  str
# ...

# %%
df.columns= df.columns.str.lower() #paso los nombres de las columnas a minusculas para facilitar lectura.

# %%
df.head(5) #imprimo las primeras 5 filas del dataframe para comprobar que se ha creado correctamente.
# Out:
#    loyalty number  year  month  flights booked  flights with companions  \
# 0          100018  2017      1               3                        0
# 1          100102  2017      1              10                        4
# 2          100140  2017      1               6                        0
# 3          100214  2017      1               0                        0
# 4          100272  2017      1               0                        0
#
#    total flights  distance  points accumulated  points redeemed  \
# 0              3      1521               152.0                0
# 1             14      2030               203.0                0
# 2              6      1200               120.0                0
# 3              0         0                 0.0                0
# 4              0         0                 0.0                0
#
#    dollar cost points redeemed          province          city postal code  \
# ...

# %%
df.columns= df.columns.str.replace(" ", "_") #reemplazo los espacios por guiones bajos.

# %%
df.head(5) #imprimo el nuevo dataframe para comprobar que se ha creado correctamente.
# Out:
#    loyalty_number  year  month  flights_booked  flights_with_companions  \
# 0          100018  2017      1               3                        0
# 1          100102  2017      1              10                        4
# 2          100140  2017      1               6                        0
# 3          100214  2017      1               0                        0
# 4          100272  2017      1               0                        0
#
#    total_flights  distance  points_accumulated  points_redeemed  \
# 0              3      1521               152.0                0
# 1             14      2030               203.0                0
# 2              6      1200               120.0                0
# 3              0         0                 0.0                0
# 4              0         0                 0.0                0
#
#    dollar_cost_points_redeemed          province          city postal_code  \
# ...

# %%
df.describe().T # busco las estadisticas descriptivas de las columnas numericas, transponiendo el resultado para que se muestre de forma mas clara.
# Out:
#                                 count           mean            std  \
# loyalty_number               403760.0  549875.383713  258961.514684
# year                         403760.0    2017.500352       0.500000
# month                        403760.0       6.501335       3.451982
# flights_booked               403760.0       4.134050       5.230064
# flights_with_companions      403760.0       1.036569       2.080472
# total_flights                403760.0       5.170619       6.526858
# distance                     403760.0    1214.460979    1434.098521
# points_accumulated           403760.0     124.263761     146.696179
# points_redeemed              403760.0      30.838587     125.758002
# dollar_cost_points_redeemed  403760.0       2.495973      10.172033
# salary                       301500.0   79258.576285   34983.929798
# clv                          403760.0    7990.864857    6863.317160
# enrollment_year              403760.0    2015.250716       1.979427
# ...
